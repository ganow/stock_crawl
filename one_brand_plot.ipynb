# %%
from bayes_regression import Regressor, plot_value

# %%
import datetime
from datetime import date

# %%
from model import (
    init,
    Brand,
    MarketType,
    IndustoryType,
    DayChart,
)
from model import database_proxy as db

# %%
init(
    MODE = 'MYSQL',
    DROP_DB = False,
    CREATE_DB = False
)
db.connect()

# %%
plot_value(Brand.get(Brand.name == u"日本オラクル"), 'max_value')
