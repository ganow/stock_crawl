# %%
from model import (
    init,
    Brand,
    MarketType,
    IndustoryType,
    DayChart,
)
from model import database_proxy as db

# %%
init(
    MODE = 'MYSQL',
    DROP_DB = False,
    CREATE_DB = False
)
db.connect()

# %%
b = Brand.get(Brand.name==u"ガンホー")

# %%
b

# %%
from datetime import date

# %%
s = date(2013,1,1)
e = date(2014,1,1)

# %%
from convert_data import get_brands_raw_value_list, get_brands_value_list

# %%
raw_data = get_brands_raw_value_list(b, 'max_value', s, e)
supplemented = get_brands_value_list(b, 'max_value', s, e)

# %%
print raw_data.shape
print supplemented.shape
# Out:
# (366,)
# (366,)

# %%
x = np.arange(366)

# %%
plot(x, supplemented, 'r-', lw=2, label='interpolated')
plot(x, raw_data, 'b.', lw=2, label='raw')
title('Data Interpolation. Company: Gunho')
legend(loc='best')

# %%
b = Brand.get(Brand.id == 1005)

# %%
raw_data = get_brands_raw_value_list(b, 'max_value', s, e)
supplemented = get_brands_value_list(b, 'max_value', s, e)

# %%
plot(x, supplemented, 'r-', lw=2, label='interpolated')
plot(x, raw_data, 'b.', lw=2, label='raw')
ylim(710,810)
legend(loc='best')
title('Data Interpolation. Company: Nikke')
